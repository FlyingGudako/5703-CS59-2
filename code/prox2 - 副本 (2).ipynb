# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import f1_score, precision_score, recall_score
tf.keras.backend.clear_session()
from tensorflow.keras.metrics import Precision, Recall

# %%
text_data_path = 'modified_text.csv'
image_metadata_path = 'indiana_projections.csv'
image_folder_path = 'images/images_normalized'

text_data = pd.read_csv(text_data_path)

image_metadata = pd.read_csv(image_metadata_path)
image_metadata['filename'] = image_metadata['filename'].apply(lambda x: os.path.join(image_folder_path, x))

merged_data = pd.merge(text_data, image_metadata[['uid', 'filename']], on='uid')

tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(merged_data['notes'])
sequences = tokenizer.texts_to_sequences(merged_data['notes'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# %%
# Image data loading and preprocessing
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    image = Image.open(image_path).convert('RGB')
    image = image.resize(target_size)
    image_array = np.array(image)
    from tensorflow.keras.applications.resnet50 import preprocess_input
    image_array = preprocess_input(image_array)
    return image_array

images = np.array([load_and_preprocess_image(img_path) for img_path in merged_data['filename']])

images_file_path = 'images.npy'
np.save(images_file_path, images)

# %%
images_file_path = 'images.npy'
images = np.load(images_file_path)
images.shape
# Out:
# (7466, 224, 224, 3)

# %%
import tensorflow as tf

class CustomAccuracy(tf.keras.metrics.Metric):
    def __init__(self, name='custom_accuracy', **kwargs):
        super(CustomAccuracy, self).__init__(name=name, **kwargs)
        self.total_correct = self.add_weight(name='total_correct', initializer='zeros', dtype=tf.float32)
        self.total_labels = self.add_weight(name='total_labels', initializer='zeros', dtype=tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):

        # The prediction results are converted to binarization
        y_pred_binary = tf.cast(y_pred > 0.5, tf.float32)

        # Condition 1: Label 0 is predicted to be positive
        condition1 = y_pred_binary[:, 0] > 0.5  # shape: (batch_size,)

        # Condition 2: Any one of the other labels is predicted to be positive
        condition2 = tf.reduce_any(y_pred_binary[:, 1:] > 0.5, axis=1)  # shape: (batch_size,)

        # Step 1: If condition 1 is true, set the other labels to 0
        condition1_expanded = tf.expand_dims(condition1, axis=1)  # shape: (batch_size, 1)
        y_pred_modified = tf.where(
            condition1_expanded,
            tf.concat([y_pred_binary[:, 0:1], tf.zeros_like(y_pred_binary[:, 1:])], axis=1),
            y_pred_binary
        )

        # Step 2: Set label 0 to 0 if condition 1 is false and Condition 2 is true
        condition2_only = tf.logical_and(tf.logical_not(condition1), condition2)  # shape: (batch_size,)
        condition2_only_expanded = tf.expand_dims(condition2_only, axis=1)  # shape: (batch_size, 1)
        y_pred_modified = tf.where(
            condition2_only_expanded,
            tf.concat([tf.zeros_like(y_pred_binary[:, 0:1]), y_pred_modified[:, 1:]], axis=1),
            y_pred_modified
        )

        # The correct prediction is computed for each label
        correct_predictions = tf.cast(tf.equal(y_pred_modified, y_true), tf.float32)

        # Calculate the total number of correct predictions for this batch
        correct_sum = tf.reduce_sum(correct_predictions)

        # Calculate the total number of tags in this batch
        labels_sum = tf.cast(tf.size(y_true), tf.float32)

        # Update the cumulative number of correct predictions and the total number of labels
        self.total_correct.assign_add(correct_sum)
        self.total_labels.assign_add(labels_sum)

    def result(self):
        """
        Returns the accuracy, making sure it's between 0 and 1.
        """
        return self.total_correct / self.total_labels

    def reset_state(self):
        """
        Reset the accumulated number of correct predictions and the total number of labels.
        """
        self.total_correct.assign(0.0)
        self.total_labels.assign(0.0)

# %%
merged_data['labels'] = merged_data['labels'].fillna('')

def process_labels(label):
    if isinstance(label, list):
        return label
    if isinstance(label, str) and label != '':
        try:
            return list(map(int, label.split(';')))
        except ValueError:
            return []
    return []

labels = merged_data['labels'].apply(process_labels)
mlb = MultiLabelBinarizer(classes=list(range(14)))  
labels = mlb.fit_transform(labels)


assert len(padded_sequences) == len(images) == len(labels), "Data lengths are inconsistent!"
padded_sequences = np.array(padded_sequences)
images = np.array(images)
labels = np.array(labels)

# Shuffle the data
padded_sequences, images, labels = shuffle(padded_sequences, images, labels, random_state=42)

# Split the data into multiple clients
num_clients = 3  
client_data_size = len(padded_sequences) // num_clients

client_datasets = []
for i in range(num_clients):
    start_index = i * client_data_size
    if i == num_clients - 1:
        end_index = len(padded_sequences)
    else:
        end_index = (i + 1) * client_data_size
    
    client_padded_sequences = padded_sequences[start_index:end_index]
    client_images = images[start_index:end_index]
    client_labels = labels[start_index:end_index]
    
    client_datasets.append((client_padded_sequences, client_images, client_labels))

# Defining the model architecture
def create_model():

    text_input = tf.keras.Input(shape=(100,), name='text_input')
    embedding_layer = tf.keras.layers.Embedding(input_dim=10000, output_dim=128)(text_input)
    lstm_layer = tf.keras.layers.LSTM(128)(embedding_layer)
    text_dense = tf.keras.layers.Dense(128, activation='relu')(lstm_layer)
    text_dropout = tf.keras.layers.Dropout(0.5)(text_dense)
    text_output = tf.keras.layers.Dense(64, activation='relu')(text_dropout)

    image_input = tf.keras.Input(shape=(224, 224, 3), name='image_input')
    base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_tensor=image_input)
    base_model.trainable = False  
    image_pooling = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    image_dense = tf.keras.layers.Dense(128, activation='relu')(image_pooling)
    image_dropout = tf.keras.layers.Dropout(0.5)(image_dense)
    image_output = tf.keras.layers.Dense(64, activation='relu')(image_dropout)
    
    combined = tf.keras.layers.Concatenate()([text_output, image_output])
    combined_dense = tf.keras.layers.Dense(128, activation='relu')(combined)
    combined_dropout = tf.keras.layers.Dropout(0.5)(combined_dense)
    final_output = tf.keras.layers.Dense(14, activation='sigmoid')(combined_dropout)
    
    model = tf.keras.Model(inputs=[text_input, image_input], outputs=final_output)
    
    return model

# FedProx
def fedprox_loss(global_weights, mu):
    def loss_fn(y_true, y_pred):
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        prox_term = 0.0
        for lw, gw in zip(model.trainable_weights, global_weights):
            prox_term += tf.nn.l2_loss(lw - gw)
        return bce + (mu / 2) * prox_term
    return loss_fn

# Initialize the global model
global_model = create_model()

num_rounds = 20  #
mu = 0.01

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
global_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[CustomAccuracy(), Precision(), Recall()])

global_metrics = []

for round_num in range(1, num_rounds + 1):
    print(f"\n===== Starting round {round_num} of federated learning =====")
    
    print("\n--- Training with FedProx aggregation ---")
    client_weights = []
    client_metrics = []
    
    # Store validation data for global evaluation
    val_text_list = []
    val_images_list = []
    val_labels_list = []

    for client_num, (client_padded_sequences, client_images, client_labels) in enumerate(client_datasets, 1):
        print(f"\n--- Training on client {client_num} ---")

        local_model = create_model()
        local_model.set_weights(global_model.get_weights())

        # Obtain global weights tensors for Proximal term
        global_weights = global_model.get_weights()
        global_weights_tensors = [tf.constant(w) for w in global_weights]

        # Separate weights for text and image layers
        text_weights_local = local_model.trainable_weights[:len(global_model.layers[1].trainable_weights)]
        image_weights_local = local_model.trainable_weights[len(global_model.layers[1].trainable_weights):]
        text_weights_global = global_weights_tensors[:len(global_model.layers[1].trainable_weights)]
        image_weights_global = global_weights_tensors[len(global_model.layers[1].trainable_weights):]

        # Proximal term for text layers
        for lw, gw in zip(text_weights_local, text_weights_global):
            if lw.shape != gw.shape:
                raise ValueError(f"Shape mismatch in text layers: local weight shape {lw.shape} and global weight shape {gw.shape}")
            prox = tf.nn.l2_loss(lw - gw)
            local_model.add_loss(lambda: (mu / 2) * prox)

        # Proximal term for image layers
        for lw, gw in zip(image_weights_local, image_weights_global):
            if lw.shape != gw.shape:
                continue  # Skip layers with mismatched shapes
            prox = tf.nn.l2_loss(lw - gw)
            local_model.add_loss(lambda: (mu / 2) * prox)

        # Compile the local model with standard loss (Proximal term added)
        local_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[CustomAccuracy()])

        # Split client data into training and validation sets
        client_X_train_text, client_X_val_text, client_X_train_images, client_X_val_images, client_y_train, client_y_val = train_test_split(
            client_padded_sequences, client_images, client_labels, test_size=0.2, random_state=client_num + 100
        )

        # Ensure data types are correct
        client_X_train_text = client_X_train_text.astype(np.int32)
        client_X_val_text = client_X_val_text.astype(np.int32)
        client_X_train_images = client_X_train_images.astype(np.float32)
        client_X_val_images = client_X_val_images.astype(np.float32)
        client_y_train = client_y_train.astype(np.float32)
        client_y_val = client_y_val.astype(np.float32)

        # Callback function
        client_model_filepath = f"client_{client_num}_round_{round_num}_fedprox_model.h5"
        model_checkpoint = ModelCheckpoint(client_model_filepath, save_best_only=True, monitor='val_loss')

        # Train the local model
        history = local_model.fit(
            {'text_input': client_X_train_text, 'image_input': client_X_train_images},
            client_y_train,
            epochs=10,  
            batch_size=8,
            validation_data=({'text_input': client_X_val_text, 'image_input': client_X_val_images}, client_y_val),
            callbacks=[model_checkpoint],
            verbose=1
        )

        # Save local model weights
        client_weights.append(local_model.get_weights())

        # Store validation data
        val_text_list.append(client_X_val_text)
        val_images_list.append(client_X_val_images)
        val_labels_list.append(client_y_val)

        client_evaluation = local_model.evaluate(
            {'text_input': client_X_val_text, 'image_input': client_X_val_images},
            client_y_val,
            verbose=0
        )
        client_metrics.append(client_evaluation)
        # Get the prediction results of the validation set
        val_predictions = local_model.predict({'text_input': client_X_val_text, 'image_input': client_X_val_images})
        val_predictions_binary = np.where(val_predictions > 0.5, 1, 0)

        # Calculate and print F1, Precision, Recall
        f1 = f1_score(client_y_val, val_predictions_binary, average='weighted', zero_division=1)
        recall = recall_score(client_y_val, val_predictions_binary, average='weighted', zero_division=1)
        precision = precision_score(client_y_val, val_predictions_binary, average='weighted', zero_division=1)

        print(f"Client {client_num} - Last epoch validation: Loss: {client_evaluation[0]}, Accuracy: {client_evaluation[1]}, F1: {f1}, Precision: {precision}, Recall: {recall}")
        print(f"--- Training on client {client_num} completed ---")

    # Aggregate client weights
    print("\n*** Aggregating client model weights (FedProx) ***")
    new_weights = []
    for weights_list in zip(*client_weights):
        new_weights.append(np.mean(weights_list, axis=0))

    # Update global model weights
    global_model.set_weights(new_weights)
    print("*** Global model weights updated (FedProx) ***")

    # Combine validation data
    combined_val_text = np.concatenate(val_text_list)
    combined_val_images = np.concatenate(val_images_list)
    combined_val_labels = np.concatenate(val_labels_list)

    combined_val_text = combined_val_text.astype(np.int32)
    combined_val_images = combined_val_images.astype(np.float32)
    combined_val_labels = combined_val_labels.astype(np.float32)

    # Evaluate global model on combined validation data
    global_evaluation = global_model.evaluate(
        {'text_input': combined_val_text, 'image_input': combined_val_images},
        combined_val_labels,
        verbose=0
    )
    global_metrics.append(global_evaluation)
    print(f"\n===== Post-round {round_num} global model evaluation (FedProx): {global_model.metrics_names} = {global_evaluation} =====")
# Out:
# ===== Starting round 1 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 14s 33ms/step - loss: 1.6360 - custom_accuracy: 0.8609 - val_loss: 1.5764 - val_custom_accuracy: 0.8841
# Epoch 2/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5914 - custom_accuracy: 0.8768 - val_loss: 1.5772 - val_custom_accuracy: 0.8855
# Epoch 3/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5800 - custom_accuracy: 0.8795 - val_loss: 1.5613 - val_custom_accuracy: 0.8891
# Epoch 4/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5716 - custom_accuracy: 0.8810 - val_loss: 1.5690 - val_custom_accuracy: 0.8883
# Epoch 5/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.5678 - custom_accuracy: 0.8826 - val_loss: 1.5591 - val_custom_accuracy: 0.8901
# Epoch 6/10
# 249/249 [==============================] - 6s 24ms/step - loss: 1.5685 - custom_accuracy: 0.8820 - val_loss: 1.5682 - val_custom_accuracy: 0.8871
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5653 - custom_accuracy: 0.8834 - val_loss: 1.5567 - val_custom_accuracy: 0.8897
# Epoch 8/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5610 - custom_accuracy: 0.8851 - val_loss: 1.5616 - val_custom_accuracy: 0.8858
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5611 - custom_accuracy: 0.8852 - val_loss: 1.5573 - val_custom_accuracy: 0.8894
# Epoch 10/10
# 249/249 [==============================] - 6s 23ms/step - loss: 1.5595 - custom_accuracy: 0.8844 - val_loss: 1.5636 - val_custom_accuracy: 0.8897
# Client 1 - Last epoch validation: Loss: 1.563597321510315, Accuracy: 0.8897016644477844, F1: 0.09886045208294415, Precision: 0.9472664657770126, Recall: 0.06683168316831682
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 24ms/step - loss: 1.6292 - custom_accuracy: 0.8687 - val_loss: 1.5801 - val_custom_accuracy: 0.8801
# Epoch 2/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5966 - custom_accuracy: 0.8773 - val_loss: 1.5901 - val_custom_accuracy: 0.8801
# Epoch 3/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5937 - custom_accuracy: 0.8786 - val_loss: 1.5797 - val_custom_accuracy: 0.8822
# Epoch 4/10
# 249/249 [==============================] - 5s 22ms/step - loss: 1.5895 - custom_accuracy: 0.8785 - val_loss: 1.5688 - val_custom_accuracy: 0.8821
# Epoch 5/10
# 249/249 [==============================] - 9s 35ms/step - loss: 1.5878 - custom_accuracy: 0.8793 - val_loss: 1.5749 - val_custom_accuracy: 0.8801
# Epoch 6/10
# 249/249 [==============================] - 10s 38ms/step - loss: 1.5853 - custom_accuracy: 0.8800 - val_loss: 1.5660 - val_custom_accuracy: 0.8807
# Epoch 7/10
# 249/249 [==============================] - 9s 34ms/step - loss: 1.5844 - custom_accuracy: 0.8792 - val_loss: 1.5658 - val_custom_accuracy: 0.8810
# Epoch 8/10
# 249/249 [==============================] - 9s 35ms/step - loss: 1.5820 - custom_accuracy: 0.8799 - val_loss: 1.5653 - val_custom_accuracy: 0.8821
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5810 - custom_accuracy: 0.8803 - val_loss: 1.5672 - val_custom_accuracy: 0.8804
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5714 - custom_accuracy: 0.8812 - val_loss: 1.5269 - val_custom_accuracy: 0.8941
# Client 2 - Last epoch validation: Loss: 1.5269076824188232, Accuracy: 0.8942914605140686, F1: 0.2872064143279289, Precision: 0.8238320449957663, Recall: 0.2751196172248804
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 21ms/step - loss: 1.6268 - custom_accuracy: 0.8679 - val_loss: 1.5756 - val_custom_accuracy: 0.8864
# Epoch 2/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5981 - custom_accuracy: 0.8769 - val_loss: 1.5723 - val_custom_accuracy: 0.8864
# Epoch 3/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5913 - custom_accuracy: 0.8775 - val_loss: 1.5633 - val_custom_accuracy: 0.8870
# Epoch 4/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5873 - custom_accuracy: 0.8779 - val_loss: 1.5664 - val_custom_accuracy: 0.8881
# Epoch 5/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5700 - custom_accuracy: 0.8812 - val_loss: 1.5248 - val_custom_accuracy: 0.8973
# Epoch 6/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5320 - custom_accuracy: 0.8948 - val_loss: 1.4969 - val_custom_accuracy: 0.9096
# Epoch 7/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5150 - custom_accuracy: 0.9005 - val_loss: 1.4908 - val_custom_accuracy: 0.9096
# Epoch 8/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5031 - custom_accuracy: 0.9043 - val_loss: 1.4889 - val_custom_accuracy: 0.9131
# Epoch 9/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4971 - custom_accuracy: 0.9067 - val_loss: 1.4828 - val_custom_accuracy: 0.9145
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4898 - custom_accuracy: 0.9097 - val_loss: 1.4765 - val_custom_accuracy: 0.9174
# Client 3 - Last epoch validation: Loss: 1.4764574766159058, Accuracy: 0.9173838496208191, F1: 0.4202564825564095, Precision: 0.838979067532176, Recall: 0.3888888888888889
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 1 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.34759292006492615, 0.8835341334342957, 0.0, 0.0] =====
#
# ===== Starting round 2 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 22ms/step - loss: 1.6151 - custom_accuracy: 0.8794 - val_loss: 1.6067 - val_custom_accuracy: 0.8848
# Epoch 2/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5751 - custom_accuracy: 0.8925 - val_loss: 1.5346 - val_custom_accuracy: 0.9046
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5260 - custom_accuracy: 0.9064 - val_loss: 1.5506 - val_custom_accuracy: 0.8888
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5146 - custom_accuracy: 0.9103 - val_loss: 1.5116 - val_custom_accuracy: 0.9115
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5069 - custom_accuracy: 0.9127 - val_loss: 1.5101 - val_custom_accuracy: 0.9132
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5014 - custom_accuracy: 0.9145 - val_loss: 1.5089 - val_custom_accuracy: 0.9128
# Epoch 7/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4983 - custom_accuracy: 0.9152 - val_loss: 1.5051 - val_custom_accuracy: 0.9161
# Epoch 8/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4946 - custom_accuracy: 0.9183 - val_loss: 1.5086 - val_custom_accuracy: 0.9132
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4937 - custom_accuracy: 0.9183 - val_loss: 1.5047 - val_custom_accuracy: 0.9135
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4909 - custom_accuracy: 0.9198 - val_loss: 1.5064 - val_custom_accuracy: 0.9128
# Client 1 - Last epoch validation: Loss: 1.5064353942871094, Accuracy: 0.9127940535545349, F1: 0.4655926040035877, Precision: 0.8161376447955105, Recall: 0.5210396039603961
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 20ms/step - loss: 1.6265 - custom_accuracy: 0.8775 - val_loss: 1.6088 - val_custom_accuracy: 0.8801
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5844 - custom_accuracy: 0.8865 - val_loss: 1.5310 - val_custom_accuracy: 0.9022
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5528 - custom_accuracy: 0.8985 - val_loss: 1.5242 - val_custom_accuracy: 0.9042
# Epoch 4/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5337 - custom_accuracy: 0.9024 - val_loss: 1.5148 - val_custom_accuracy: 0.9114
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5270 - custom_accuracy: 0.9060 - val_loss: 1.5146 - val_custom_accuracy: 0.9111
# Epoch 6/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5214 - custom_accuracy: 0.9073 - val_loss: 1.5096 - val_custom_accuracy: 0.9127
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5177 - custom_accuracy: 0.9089 - val_loss: 1.5117 - val_custom_accuracy: 0.9132
# Epoch 8/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5159 - custom_accuracy: 0.9101 - val_loss: 1.5105 - val_custom_accuracy: 0.9132
# Epoch 9/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5128 - custom_accuracy: 0.9114 - val_loss: 1.5080 - val_custom_accuracy: 0.9151
# Epoch 10/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5095 - custom_accuracy: 0.9131 - val_loss: 1.5059 - val_custom_accuracy: 0.9141
# Client 2 - Last epoch validation: Loss: 1.505852222442627, Accuracy: 0.9140849113464355, F1: 0.46677318116364364, Precision: 0.8414634775256585, Recall: 0.4700956937799043
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 22ms/step - loss: 1.6027 - custom_accuracy: 0.8837 - val_loss: 1.5217 - val_custom_accuracy: 0.9106
# Epoch 2/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5397 - custom_accuracy: 0.9007 - val_loss: 1.5114 - val_custom_accuracy: 0.9102
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5260 - custom_accuracy: 0.9033 - val_loss: 1.5120 - val_custom_accuracy: 0.9101
# Epoch 4/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.5195 - custom_accuracy: 0.9061 - val_loss: 1.5058 - val_custom_accuracy: 0.9154
# Epoch 5/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.5145 - custom_accuracy: 0.9090 - val_loss: 1.5058 - val_custom_accuracy: 0.9134
# Epoch 6/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.5089 - custom_accuracy: 0.9114 - val_loss: 1.5033 - val_custom_accuracy: 0.9139
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5072 - custom_accuracy: 0.9123 - val_loss: 1.5046 - val_custom_accuracy: 0.9139
# Epoch 8/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5034 - custom_accuracy: 0.9134 - val_loss: 1.4999 - val_custom_accuracy: 0.9162
# Epoch 9/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.5001 - custom_accuracy: 0.9136 - val_loss: 1.4992 - val_custom_accuracy: 0.9172
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.5012 - custom_accuracy: 0.9132 - val_loss: 1.4968 - val_custom_accuracy: 0.9157
# Client 3 - Last epoch validation: Loss: 1.4967957735061646, Accuracy: 0.9156626462936401, F1: 0.44159595954988906, Precision: 0.8305973089530135, Recall: 0.4356060606060606
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 2 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.3371940851211548, 0.8835341334342957, 0.0, 0.0] =====
#
# ===== Starting round 3 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 21ms/step - loss: 1.5277 - custom_accuracy: 0.9113 - val_loss: 1.5101 - val_custom_accuracy: 0.9134
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5047 - custom_accuracy: 0.9191 - val_loss: 1.5123 - val_custom_accuracy: 0.9142
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4981 - custom_accuracy: 0.9196 - val_loss: 1.4979 - val_custom_accuracy: 0.9165
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4878 - custom_accuracy: 0.9224 - val_loss: 1.4964 - val_custom_accuracy: 0.9207
# Epoch 5/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4797 - custom_accuracy: 0.9255 - val_loss: 1.4965 - val_custom_accuracy: 0.9260
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4732 - custom_accuracy: 0.9295 - val_loss: 1.4886 - val_custom_accuracy: 0.9261
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4678 - custom_accuracy: 0.9318 - val_loss: 1.4873 - val_custom_accuracy: 0.9257
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4650 - custom_accuracy: 0.9332 - val_loss: 1.4817 - val_custom_accuracy: 0.9297
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4596 - custom_accuracy: 0.9337 - val_loss: 1.4813 - val_custom_accuracy: 0.9291
# Epoch 10/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4580 - custom_accuracy: 0.9345 - val_loss: 1.4925 - val_custom_accuracy: 0.9261
# Client 1 - Last epoch validation: Loss: 1.4924923181533813, Accuracy: 0.9261330962181091, F1: 0.5599786149556393, Precision: 0.8358434275172293, Recall: 0.5792079207920792
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 6s 19ms/step - loss: 1.5426 - custom_accuracy: 0.9043 - val_loss: 1.5251 - val_custom_accuracy: 0.9168
# Epoch 2/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5222 - custom_accuracy: 0.9096 - val_loss: 1.5106 - val_custom_accuracy: 0.9167
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5116 - custom_accuracy: 0.9139 - val_loss: 1.5044 - val_custom_accuracy: 0.9201
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5044 - custom_accuracy: 0.9162 - val_loss: 1.5031 - val_custom_accuracy: 0.9213
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4992 - custom_accuracy: 0.9197 - val_loss: 1.4992 - val_custom_accuracy: 0.9233
# Epoch 6/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4927 - custom_accuracy: 0.9225 - val_loss: 1.5032 - val_custom_accuracy: 0.9264
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4886 - custom_accuracy: 0.9232 - val_loss: 1.4989 - val_custom_accuracy: 0.9227
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4827 - custom_accuracy: 0.9260 - val_loss: 1.4975 - val_custom_accuracy: 0.9253
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4800 - custom_accuracy: 0.9265 - val_loss: 1.4961 - val_custom_accuracy: 0.9276
# Epoch 10/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4767 - custom_accuracy: 0.9289 - val_loss: 1.5039 - val_custom_accuracy: 0.9269
# Client 2 - Last epoch validation: Loss: 1.5039483308792114, Accuracy: 0.9268502593040466, F1: 0.543342987496642, Precision: 0.8225051588941913, Recall: 0.5514354066985646
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 6s 19ms/step - loss: 1.5368 - custom_accuracy: 0.9035 - val_loss: 1.5088 - val_custom_accuracy: 0.9161
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5211 - custom_accuracy: 0.9095 - val_loss: 1.5055 - val_custom_accuracy: 0.9151
# Epoch 3/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.5129 - custom_accuracy: 0.9122 - val_loss: 1.5023 - val_custom_accuracy: 0.9185
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.5073 - custom_accuracy: 0.9120 - val_loss: 1.4998 - val_custom_accuracy: 0.9151
# Epoch 5/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.5035 - custom_accuracy: 0.9123 - val_loss: 1.4993 - val_custom_accuracy: 0.9172
# Epoch 6/10
# 249/249 [==============================] - 3s 14ms/step - loss: 1.5015 - custom_accuracy: 0.9139 - val_loss: 1.5021 - val_custom_accuracy: 0.9197
# Epoch 7/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4971 - custom_accuracy: 0.9136 - val_loss: 1.4972 - val_custom_accuracy: 0.9188
# Epoch 8/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4949 - custom_accuracy: 0.9162 - val_loss: 1.4951 - val_custom_accuracy: 0.9207
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4913 - custom_accuracy: 0.9156 - val_loss: 1.4925 - val_custom_accuracy: 0.9240
# Epoch 10/10
# 249/249 [==============================] - 3s 14ms/step - loss: 1.4861 - custom_accuracy: 0.9191 - val_loss: 1.4943 - val_custom_accuracy: 0.9225
# Client 3 - Last epoch validation: Loss: 1.4943052530288696, Accuracy: 0.9225473403930664, F1: 0.46862025997060197, Precision: 0.856669190361286, Recall: 0.46085858585858586
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 3 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.19558225572109222, 0.9190571904182434, 0.6919896602630615, 0.5496715903282166] =====
#
# ===== Starting round 4 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 6s 19ms/step - loss: 1.4953 - custom_accuracy: 0.9245 - val_loss: 1.4968 - val_custom_accuracy: 0.9247
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4760 - custom_accuracy: 0.9330 - val_loss: 1.4847 - val_custom_accuracy: 0.9293
# Epoch 3/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4639 - custom_accuracy: 0.9348 - val_loss: 1.4823 - val_custom_accuracy: 0.9320
# Epoch 4/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4567 - custom_accuracy: 0.9385 - val_loss: 1.4801 - val_custom_accuracy: 0.9314
# Epoch 5/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4536 - custom_accuracy: 0.9398 - val_loss: 1.4858 - val_custom_accuracy: 0.9327
# Epoch 6/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4503 - custom_accuracy: 0.9401 - val_loss: 1.4850 - val_custom_accuracy: 0.9357
# Epoch 7/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4483 - custom_accuracy: 0.9413 - val_loss: 1.4816 - val_custom_accuracy: 0.9353
# Epoch 8/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4439 - custom_accuracy: 0.9417 - val_loss: 1.4861 - val_custom_accuracy: 0.9356
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4433 - custom_accuracy: 0.9419 - val_loss: 1.4908 - val_custom_accuracy: 0.9320
# Epoch 10/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4419 - custom_accuracy: 0.9418 - val_loss: 1.4878 - val_custom_accuracy: 0.9332
# Client 1 - Last epoch validation: Loss: 1.4877889156341553, Accuracy: 0.933161199092865, F1: 0.6303109033008449, Precision: 0.7483623217613397, Recall: 0.6485148514851485
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.5134 - custom_accuracy: 0.9165 - val_loss: 1.4957 - val_custom_accuracy: 0.9266
# Epoch 2/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4885 - custom_accuracy: 0.9280 - val_loss: 1.4925 - val_custom_accuracy: 0.9291
# Epoch 3/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.4796 - custom_accuracy: 0.9300 - val_loss: 1.4896 - val_custom_accuracy: 0.9290
# Epoch 4/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4717 - custom_accuracy: 0.9331 - val_loss: 1.4932 - val_custom_accuracy: 0.9326
# Epoch 5/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4663 - custom_accuracy: 0.9352 - val_loss: 1.4873 - val_custom_accuracy: 0.9349
# Epoch 6/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4612 - custom_accuracy: 0.9359 - val_loss: 1.4969 - val_custom_accuracy: 0.9327
# Epoch 7/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4603 - custom_accuracy: 0.9378 - val_loss: 1.4935 - val_custom_accuracy: 0.9317
# Epoch 8/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4548 - custom_accuracy: 0.9399 - val_loss: 1.4917 - val_custom_accuracy: 0.9343
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4526 - custom_accuracy: 0.9403 - val_loss: 1.4961 - val_custom_accuracy: 0.9333
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4478 - custom_accuracy: 0.9423 - val_loss: 1.4993 - val_custom_accuracy: 0.9376
# Client 2 - Last epoch validation: Loss: 1.4993191957473755, Accuracy: 0.9376075863838196, F1: 0.6406297556587155, Precision: 0.8457269822341084, Recall: 0.6375598086124402
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 23ms/step - loss: 1.5099 - custom_accuracy: 0.9168 - val_loss: 1.4849 - val_custom_accuracy: 0.9261
# Epoch 2/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4875 - custom_accuracy: 0.9250 - val_loss: 1.4781 - val_custom_accuracy: 0.9293
# Epoch 3/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4795 - custom_accuracy: 0.9275 - val_loss: 1.4737 - val_custom_accuracy: 0.9320
# Epoch 4/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4709 - custom_accuracy: 0.9312 - val_loss: 1.4704 - val_custom_accuracy: 0.9347
# Epoch 5/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4654 - custom_accuracy: 0.9335 - val_loss: 1.4731 - val_custom_accuracy: 0.9334
# Epoch 6/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4625 - custom_accuracy: 0.9340 - val_loss: 1.4707 - val_custom_accuracy: 0.9345
# Epoch 7/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4583 - custom_accuracy: 0.9355 - val_loss: 1.4691 - val_custom_accuracy: 0.9357
# Epoch 8/10
# 249/249 [==============================] - 4s 14ms/step - loss: 1.4537 - custom_accuracy: 0.9378 - val_loss: 1.4711 - val_custom_accuracy: 0.9373
# Epoch 9/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4512 - custom_accuracy: 0.9371 - val_loss: 1.4675 - val_custom_accuracy: 0.9380
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4468 - custom_accuracy: 0.9395 - val_loss: 1.4721 - val_custom_accuracy: 0.9389
# Client 3 - Last epoch validation: Loss: 1.4720808267593384, Accuracy: 0.9388984441757202, F1: 0.6334373469160899, Precision: 0.811651508206105, Recall: 0.6123737373737373
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 4 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.16054491698741913, 0.9347389340400696, 0.7575757503509521, 0.6465517282485962] =====
#
# ===== Starting round 5 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 22ms/step - loss: 1.4734 - custom_accuracy: 0.9355 - val_loss: 1.4777 - val_custom_accuracy: 0.9343
# Epoch 2/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4536 - custom_accuracy: 0.9403 - val_loss: 1.4733 - val_custom_accuracy: 0.9373
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4454 - custom_accuracy: 0.9435 - val_loss: 1.4678 - val_custom_accuracy: 0.9382
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4397 - custom_accuracy: 0.9447 - val_loss: 1.4726 - val_custom_accuracy: 0.9375
# Epoch 5/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4340 - custom_accuracy: 0.9462 - val_loss: 1.4633 - val_custom_accuracy: 0.9379
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4320 - custom_accuracy: 0.9475 - val_loss: 1.4718 - val_custom_accuracy: 0.9383
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4291 - custom_accuracy: 0.9500 - val_loss: 1.4730 - val_custom_accuracy: 0.9399
# Epoch 8/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4257 - custom_accuracy: 0.9494 - val_loss: 1.4811 - val_custom_accuracy: 0.9385
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4221 - custom_accuracy: 0.9509 - val_loss: 1.4772 - val_custom_accuracy: 0.9423
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4229 - custom_accuracy: 0.9507 - val_loss: 1.4843 - val_custom_accuracy: 0.9400
# Client 1 - Last epoch validation: Loss: 1.4843002557754517, Accuracy: 0.9400458931922913, F1: 0.6668100633585429, Precision: 0.7722590330038992, Recall: 0.6757425742574258
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.4890 - custom_accuracy: 0.9288 - val_loss: 1.4910 - val_custom_accuracy: 0.9309
# Epoch 2/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4686 - custom_accuracy: 0.9327 - val_loss: 1.4997 - val_custom_accuracy: 0.9324
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4584 - custom_accuracy: 0.9365 - val_loss: 1.5013 - val_custom_accuracy: 0.9353
# Epoch 4/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4538 - custom_accuracy: 0.9379 - val_loss: 1.5190 - val_custom_accuracy: 0.9345
# Epoch 5/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4511 - custom_accuracy: 0.9398 - val_loss: 1.5009 - val_custom_accuracy: 0.9322
# Epoch 6/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4476 - custom_accuracy: 0.9405 - val_loss: 1.5229 - val_custom_accuracy: 0.9360
# Epoch 7/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4423 - custom_accuracy: 0.9422 - val_loss: 1.5108 - val_custom_accuracy: 0.9388
# Epoch 8/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4394 - custom_accuracy: 0.9438 - val_loss: 1.5122 - val_custom_accuracy: 0.9393
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4366 - custom_accuracy: 0.9441 - val_loss: 1.5134 - val_custom_accuracy: 0.9395
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4346 - custom_accuracy: 0.9470 - val_loss: 1.5272 - val_custom_accuracy: 0.9395
# Client 2 - Last epoch validation: Loss: 1.5271916389465332, Accuracy: 0.9394721984863281, F1: 0.6854113969417942, Precision: 0.7940651995290431, Recall: 0.6794258373205742
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 22ms/step - loss: 1.4823 - custom_accuracy: 0.9284 - val_loss: 1.4629 - val_custom_accuracy: 0.9360
# Epoch 2/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4655 - custom_accuracy: 0.9339 - val_loss: 1.4625 - val_custom_accuracy: 0.9379
# Epoch 3/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4547 - custom_accuracy: 0.9368 - val_loss: 1.4525 - val_custom_accuracy: 0.9418
# Epoch 4/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4489 - custom_accuracy: 0.9406 - val_loss: 1.4502 - val_custom_accuracy: 0.9412
# Epoch 5/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4429 - custom_accuracy: 0.9413 - val_loss: 1.4535 - val_custom_accuracy: 0.9432
# Epoch 6/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4399 - custom_accuracy: 0.9431 - val_loss: 1.4527 - val_custom_accuracy: 0.9433
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4357 - custom_accuracy: 0.9449 - val_loss: 1.4559 - val_custom_accuracy: 0.9452
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4341 - custom_accuracy: 0.9463 - val_loss: 1.4519 - val_custom_accuracy: 0.9461
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4316 - custom_accuracy: 0.9456 - val_loss: 1.4481 - val_custom_accuracy: 0.9465
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4283 - custom_accuracy: 0.9484 - val_loss: 1.4507 - val_custom_accuracy: 0.9491
# Client 3 - Last epoch validation: Loss: 1.450679063796997, Accuracy: 0.9490820169448853, F1: 0.7257577693367463, Precision: 0.826764062704416, Recall: 0.7133838383838383
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 5 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.14799605309963226, 0.9439185261726379, 0.7892808318138123, 0.7073070406913757] =====
#
# ===== Starting round 6 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.4574 - custom_accuracy: 0.9410 - val_loss: 1.4675 - val_custom_accuracy: 0.9385
# Epoch 2/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4399 - custom_accuracy: 0.9462 - val_loss: 1.4680 - val_custom_accuracy: 0.9406
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4286 - custom_accuracy: 0.9483 - val_loss: 1.4718 - val_custom_accuracy: 0.9435
# Epoch 4/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4237 - custom_accuracy: 0.9511 - val_loss: 1.4718 - val_custom_accuracy: 0.9432
# Epoch 5/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4216 - custom_accuracy: 0.9525 - val_loss: 1.4710 - val_custom_accuracy: 0.9448
# Epoch 6/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4178 - custom_accuracy: 0.9525 - val_loss: 1.4736 - val_custom_accuracy: 0.9426
# Epoch 7/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4147 - custom_accuracy: 0.9537 - val_loss: 1.4832 - val_custom_accuracy: 0.9454
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4136 - custom_accuracy: 0.9538 - val_loss: 1.4768 - val_custom_accuracy: 0.9442
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4098 - custom_accuracy: 0.9553 - val_loss: 1.4866 - val_custom_accuracy: 0.9448
# Epoch 10/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4087 - custom_accuracy: 0.9564 - val_loss: 1.4864 - val_custom_accuracy: 0.9435
# Client 1 - Last epoch validation: Loss: 1.4864448308944702, Accuracy: 0.9434882402420044, F1: 0.7111830607432696, Precision: 0.7718318992514253, Recall: 0.7227722772277227
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 20ms/step - loss: 1.4700 - custom_accuracy: 0.9331 - val_loss: 1.4811 - val_custom_accuracy: 0.9378
# Epoch 2/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4491 - custom_accuracy: 0.9416 - val_loss: 1.4925 - val_custom_accuracy: 0.9400
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4410 - custom_accuracy: 0.9435 - val_loss: 1.4878 - val_custom_accuracy: 0.9429
# Epoch 4/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4348 - custom_accuracy: 0.9457 - val_loss: 1.4889 - val_custom_accuracy: 0.9445
# Epoch 5/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4315 - custom_accuracy: 0.9458 - val_loss: 1.4998 - val_custom_accuracy: 0.9435
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4294 - custom_accuracy: 0.9491 - val_loss: 1.5001 - val_custom_accuracy: 0.9445
# Epoch 7/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4277 - custom_accuracy: 0.9496 - val_loss: 1.4895 - val_custom_accuracy: 0.9425
# Epoch 8/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4238 - custom_accuracy: 0.9503 - val_loss: 1.4848 - val_custom_accuracy: 0.9438
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4225 - custom_accuracy: 0.9521 - val_loss: 1.5094 - val_custom_accuracy: 0.9462
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4209 - custom_accuracy: 0.9518 - val_loss: 1.5105 - val_custom_accuracy: 0.9446
# Client 2 - Last epoch validation: Loss: 1.5105243921279907, Accuracy: 0.9446356892585754, F1: 0.7150001532960876, Precision: 0.8205114908602894, Recall: 0.7200956937799043
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 23ms/step - loss: 1.4750 - custom_accuracy: 0.9345 - val_loss: 1.4450 - val_custom_accuracy: 0.9484
# Epoch 2/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4472 - custom_accuracy: 0.9413 - val_loss: 1.4422 - val_custom_accuracy: 0.9485
# Epoch 3/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4387 - custom_accuracy: 0.9439 - val_loss: 1.4416 - val_custom_accuracy: 0.9482
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4339 - custom_accuracy: 0.9464 - val_loss: 1.4449 - val_custom_accuracy: 0.9498
# Epoch 5/10
# 249/249 [==============================] - 30s 121ms/step - loss: 1.4272 - custom_accuracy: 0.9470 - val_loss: 1.4392 - val_custom_accuracy: 0.9509
# Epoch 6/10
# 249/249 [==============================] - 6s 23ms/step - loss: 1.4247 - custom_accuracy: 0.9499 - val_loss: 1.4416 - val_custom_accuracy: 0.9507
# Epoch 7/10
# 249/249 [==============================] - 12s 47ms/step - loss: 1.4224 - custom_accuracy: 0.9498 - val_loss: 1.4399 - val_custom_accuracy: 0.9497
# Epoch 8/10
# 249/249 [==============================] - 11s 44ms/step - loss: 1.4181 - custom_accuracy: 0.9531 - val_loss: 1.4435 - val_custom_accuracy: 0.9508
# Epoch 9/10
# 249/249 [==============================] - 6s 22ms/step - loss: 1.4207 - custom_accuracy: 0.9512 - val_loss: 1.4436 - val_custom_accuracy: 0.9512
# Epoch 10/10
# 249/249 [==============================] - 8s 32ms/step - loss: 1.4181 - custom_accuracy: 0.9533 - val_loss: 1.4466 - val_custom_accuracy: 0.9520
# Client 3 - Last epoch validation: Loss: 1.4466174840927124, Accuracy: 0.9519506692886353, F1: 0.7497961730391993, Precision: 0.8111872618551809, Recall: 0.7310606060606061
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 6 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.13608042895793915, 0.9508510231971741, 0.8202911615371704, 0.7401477694511414] =====
#
# ===== Starting round 7 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 11s 36ms/step - loss: 1.4509 - custom_accuracy: 0.9467 - val_loss: 1.4632 - val_custom_accuracy: 0.9436
# Epoch 2/10
# 249/249 [==============================] - 8s 31ms/step - loss: 1.4281 - custom_accuracy: 0.9505 - val_loss: 1.4606 - val_custom_accuracy: 0.9449
# Epoch 3/10
# 249/249 [==============================] - 8s 30ms/step - loss: 1.4209 - custom_accuracy: 0.9534 - val_loss: 1.4638 - val_custom_accuracy: 0.9471
# Epoch 4/10
# 249/249 [==============================] - 11s 46ms/step - loss: 1.4155 - custom_accuracy: 0.9561 - val_loss: 1.4666 - val_custom_accuracy: 0.9454
# Epoch 5/10
# 249/249 [==============================] - 9s 37ms/step - loss: 1.4119 - custom_accuracy: 0.9571 - val_loss: 1.4679 - val_custom_accuracy: 0.9478
# Epoch 6/10
# 249/249 [==============================] - 7s 29ms/step - loss: 1.4098 - custom_accuracy: 0.9577 - val_loss: 1.4630 - val_custom_accuracy: 0.9488
# Epoch 7/10
# 249/249 [==============================] - 6s 25ms/step - loss: 1.4068 - custom_accuracy: 0.9580 - val_loss: 1.4723 - val_custom_accuracy: 0.9487
# Epoch 8/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4024 - custom_accuracy: 0.9601 - val_loss: 1.4776 - val_custom_accuracy: 0.9484
# Epoch 9/10
# 249/249 [==============================] - 5s 22ms/step - loss: 1.4015 - custom_accuracy: 0.9601 - val_loss: 1.4865 - val_custom_accuracy: 0.9489
# Epoch 10/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4022 - custom_accuracy: 0.9603 - val_loss: 1.4873 - val_custom_accuracy: 0.9488
# Client 1 - Last epoch validation: Loss: 1.487256646156311, Accuracy: 0.9487951993942261, F1: 0.742309103613213, Precision: 0.797341879680597, Recall: 0.7561881188118812
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 21ms/step - loss: 1.4633 - custom_accuracy: 0.9392 - val_loss: 1.4724 - val_custom_accuracy: 0.9412
# Epoch 2/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4400 - custom_accuracy: 0.9463 - val_loss: 1.4714 - val_custom_accuracy: 0.9443
# Epoch 3/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4275 - custom_accuracy: 0.9497 - val_loss: 1.4830 - val_custom_accuracy: 0.9456
# Epoch 4/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4227 - custom_accuracy: 0.9517 - val_loss: 1.4832 - val_custom_accuracy: 0.9488
# Epoch 5/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.4220 - custom_accuracy: 0.9530 - val_loss: 1.4707 - val_custom_accuracy: 0.9492
# Epoch 6/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4196 - custom_accuracy: 0.9529 - val_loss: 1.4799 - val_custom_accuracy: 0.9508
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4137 - custom_accuracy: 0.9562 - val_loss: 1.4874 - val_custom_accuracy: 0.9504
# Epoch 8/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4132 - custom_accuracy: 0.9558 - val_loss: 1.4888 - val_custom_accuracy: 0.9504
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4105 - custom_accuracy: 0.9560 - val_loss: 1.4888 - val_custom_accuracy: 0.9502
# Epoch 10/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4072 - custom_accuracy: 0.9580 - val_loss: 1.5050 - val_custom_accuracy: 0.9517
# Client 2 - Last epoch validation: Loss: 1.505039930343628, Accuracy: 0.9516637921333313, F1: 0.7548530013183945, Precision: 0.7916186727493968, Recall: 0.7667464114832536
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 25ms/step - loss: 1.4626 - custom_accuracy: 0.9401 - val_loss: 1.4330 - val_custom_accuracy: 0.9515
# Epoch 2/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4386 - custom_accuracy: 0.9456 - val_loss: 1.4336 - val_custom_accuracy: 0.9522
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4268 - custom_accuracy: 0.9507 - val_loss: 1.4367 - val_custom_accuracy: 0.9524
# Epoch 4/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4215 - custom_accuracy: 0.9514 - val_loss: 1.4384 - val_custom_accuracy: 0.9540
# Epoch 5/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4171 - custom_accuracy: 0.9530 - val_loss: 1.4361 - val_custom_accuracy: 0.9550
# Epoch 6/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4139 - custom_accuracy: 0.9558 - val_loss: 1.4353 - val_custom_accuracy: 0.9552
# Epoch 7/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.4116 - custom_accuracy: 0.9560 - val_loss: 1.4305 - val_custom_accuracy: 0.9554
# Epoch 8/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4075 - custom_accuracy: 0.9573 - val_loss: 1.4315 - val_custom_accuracy: 0.9571
# Epoch 9/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4065 - custom_accuracy: 0.9583 - val_loss: 1.4357 - val_custom_accuracy: 0.9568
# Epoch 10/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4054 - custom_accuracy: 0.9578 - val_loss: 1.4406 - val_custom_accuracy: 0.9571
# Client 3 - Last epoch validation: Loss: 1.4405728578567505, Accuracy: 0.9571141600608826, F1: 0.7725202365897322, Precision: 0.8129793480431685, Recall: 0.7727272727272727
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 7 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.1354515701532364, 0.9558233022689819, 0.8312883377075195, 0.7787356376647949] =====
#
# ===== Starting round 8 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 25ms/step - loss: 1.4402 - custom_accuracy: 0.9511 - val_loss: 1.4687 - val_custom_accuracy: 0.9498
# Epoch 2/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.4263 - custom_accuracy: 0.9544 - val_loss: 1.4617 - val_custom_accuracy: 0.9499
# Epoch 3/10
# 249/249 [==============================] - 6s 22ms/step - loss: 1.4094 - custom_accuracy: 0.9578 - val_loss: 1.4584 - val_custom_accuracy: 0.9495
# Epoch 4/10
# 249/249 [==============================] - 5s 22ms/step - loss: 1.4058 - custom_accuracy: 0.9587 - val_loss: 1.4563 - val_custom_accuracy: 0.9522
# Epoch 5/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4022 - custom_accuracy: 0.9610 - val_loss: 1.4617 - val_custom_accuracy: 0.9527
# Epoch 6/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4012 - custom_accuracy: 0.9618 - val_loss: 1.4615 - val_custom_accuracy: 0.9521
# Epoch 7/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.3984 - custom_accuracy: 0.9632 - val_loss: 1.4736 - val_custom_accuracy: 0.9530
# Epoch 8/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3959 - custom_accuracy: 0.9631 - val_loss: 1.4606 - val_custom_accuracy: 0.9561
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3938 - custom_accuracy: 0.9658 - val_loss: 1.4633 - val_custom_accuracy: 0.9530
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3946 - custom_accuracy: 0.9650 - val_loss: 1.4749 - val_custom_accuracy: 0.9557
# Client 1 - Last epoch validation: Loss: 1.474873661994934, Accuracy: 0.9556798338890076, F1: 0.7712327403269439, Precision: 0.8302154953544442, Recall: 0.7722772277227723
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 24ms/step - loss: 1.4557 - custom_accuracy: 0.9444 - val_loss: 1.4688 - val_custom_accuracy: 0.9488
# Epoch 2/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.4292 - custom_accuracy: 0.9501 - val_loss: 1.4630 - val_custom_accuracy: 0.9489
# Epoch 3/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4207 - custom_accuracy: 0.9534 - val_loss: 1.4626 - val_custom_accuracy: 0.9497
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4158 - custom_accuracy: 0.9552 - val_loss: 1.4735 - val_custom_accuracy: 0.9531
# Epoch 5/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4091 - custom_accuracy: 0.9570 - val_loss: 1.4815 - val_custom_accuracy: 0.9544
# Epoch 6/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.4116 - custom_accuracy: 0.9580 - val_loss: 1.4957 - val_custom_accuracy: 0.9538
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.4061 - custom_accuracy: 0.9592 - val_loss: 1.4810 - val_custom_accuracy: 0.9530
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4014 - custom_accuracy: 0.9607 - val_loss: 1.4912 - val_custom_accuracy: 0.9552
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4013 - custom_accuracy: 0.9618 - val_loss: 1.4915 - val_custom_accuracy: 0.9537
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3970 - custom_accuracy: 0.9635 - val_loss: 1.5053 - val_custom_accuracy: 0.9555
# Client 2 - Last epoch validation: Loss: 1.5052831172943115, Accuracy: 0.955536425113678, F1: 0.777567390021877, Precision: 0.8368907290610959, Recall: 0.7739234449760766
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 20ms/step - loss: 1.4597 - custom_accuracy: 0.9425 - val_loss: 1.4254 - val_custom_accuracy: 0.9551
# Epoch 2/10
# 249/249 [==============================] - 4s 18ms/step - loss: 1.4220 - custom_accuracy: 0.9533 - val_loss: 1.4252 - val_custom_accuracy: 0.9557
# Epoch 3/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4142 - custom_accuracy: 0.9557 - val_loss: 1.4280 - val_custom_accuracy: 0.9574
# Epoch 4/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4093 - custom_accuracy: 0.9568 - val_loss: 1.4284 - val_custom_accuracy: 0.9601
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4055 - custom_accuracy: 0.9592 - val_loss: 1.4319 - val_custom_accuracy: 0.9614
# Epoch 6/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4045 - custom_accuracy: 0.9588 - val_loss: 1.4345 - val_custom_accuracy: 0.9573
# Epoch 7/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4035 - custom_accuracy: 0.9595 - val_loss: 1.4341 - val_custom_accuracy: 0.9614
# Epoch 8/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.4003 - custom_accuracy: 0.9606 - val_loss: 1.4402 - val_custom_accuracy: 0.9633
# Epoch 9/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3989 - custom_accuracy: 0.9619 - val_loss: 1.4375 - val_custom_accuracy: 0.9636
# Epoch 10/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3964 - custom_accuracy: 0.9622 - val_loss: 1.4386 - val_custom_accuracy: 0.9620
# Client 3 - Last epoch validation: Loss: 1.4386212825775146, Accuracy: 0.9619908332824707, F1: 0.8069383146002364, Precision: 0.8575172486575843, Recall: 0.8055555555555556
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 8 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.12318968027830124, 0.9616561532020569, 0.8540493845939636, 0.8095238208770752] =====
#
# ===== Starting round 9 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 20ms/step - loss: 1.4309 - custom_accuracy: 0.9537 - val_loss: 1.4504 - val_custom_accuracy: 0.9530
# Epoch 2/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.4098 - custom_accuracy: 0.9599 - val_loss: 1.4580 - val_custom_accuracy: 0.9555
# Epoch 3/10
# 249/249 [==============================] - 5s 18ms/step - loss: 1.4020 - custom_accuracy: 0.9628 - val_loss: 1.4452 - val_custom_accuracy: 0.9564
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3990 - custom_accuracy: 0.9635 - val_loss: 1.4468 - val_custom_accuracy: 0.9571
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3954 - custom_accuracy: 0.9657 - val_loss: 1.4475 - val_custom_accuracy: 0.9584
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3923 - custom_accuracy: 0.9661 - val_loss: 1.4496 - val_custom_accuracy: 0.9594
# Epoch 7/10
# 249/249 [==============================] - 5s 19ms/step - loss: 1.3909 - custom_accuracy: 0.9662 - val_loss: 1.4719 - val_custom_accuracy: 0.9596
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3908 - custom_accuracy: 0.9677 - val_loss: 1.4517 - val_custom_accuracy: 0.9604
# Epoch 9/10
# ...
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3609 - custom_accuracy: 0.9810 - val_loss: 1.4282 - val_custom_accuracy: 0.9738
# Client 1 - Last epoch validation: Loss: 1.4282490015029907, Accuracy: 0.9737521409988403, F1: 0.866644152648046, Precision: 0.9132648333524973, Recall: 0.8576732673267327
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 23ms/step - loss: 1.4117 - custom_accuracy: 0.9654 - val_loss: 1.4897 - val_custom_accuracy: 0.9672
# Epoch 2/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3913 - custom_accuracy: 0.9700 - val_loss: 1.4654 - val_custom_accuracy: 0.9710
# Epoch 3/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3795 - custom_accuracy: 0.9723 - val_loss: 1.4631 - val_custom_accuracy: 0.9722
# Epoch 4/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3747 - custom_accuracy: 0.9757 - val_loss: 1.4711 - val_custom_accuracy: 0.9719
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3731 - custom_accuracy: 0.9752 - val_loss: 1.4732 - val_custom_accuracy: 0.9745
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3712 - custom_accuracy: 0.9762 - val_loss: 1.4795 - val_custom_accuracy: 0.9732
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3690 - custom_accuracy: 0.9768 - val_loss: 1.4743 - val_custom_accuracy: 0.9732
# Epoch 8/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3666 - custom_accuracy: 0.9771 - val_loss: 1.4871 - val_custom_accuracy: 0.9723
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3692 - custom_accuracy: 0.9782 - val_loss: 1.4836 - val_custom_accuracy: 0.9745
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3654 - custom_accuracy: 0.9786 - val_loss: 1.4917 - val_custom_accuracy: 0.9759
# Client 2 - Last epoch validation: Loss: 1.4917290210723877, Accuracy: 0.9759036302566528, F1: 0.883167051787795, Precision: 0.9213224225768158, Recall: 0.8648325358851675
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 23ms/step - loss: 1.4295 - custom_accuracy: 0.9681 - val_loss: 1.4134 - val_custom_accuracy: 0.9738
# Epoch 2/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3858 - custom_accuracy: 0.9713 - val_loss: 1.4062 - val_custom_accuracy: 0.9736
# Epoch 3/10
# 249/249 [==============================] - 5s 20ms/step - loss: 1.3736 - custom_accuracy: 0.9757 - val_loss: 1.4033 - val_custom_accuracy: 0.9749
# Epoch 4/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3694 - custom_accuracy: 0.9770 - val_loss: 1.4046 - val_custom_accuracy: 0.9748
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3686 - custom_accuracy: 0.9776 - val_loss: 1.4062 - val_custom_accuracy: 0.9748
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3698 - custom_accuracy: 0.9768 - val_loss: 1.4073 - val_custom_accuracy: 0.9756
# Epoch 7/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3655 - custom_accuracy: 0.9787 - val_loss: 1.4125 - val_custom_accuracy: 0.9753
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3666 - custom_accuracy: 0.9782 - val_loss: 1.4136 - val_custom_accuracy: 0.9735
# Epoch 9/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3640 - custom_accuracy: 0.9792 - val_loss: 1.4091 - val_custom_accuracy: 0.9742
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3652 - custom_accuracy: 0.9787 - val_loss: 1.4099 - val_custom_accuracy: 0.9772
# Client 3 - Last epoch validation: Loss: 1.409895658493042, Accuracy: 0.9771944880485535, F1: 0.8900378724860296, Precision: 0.9128426594361739, Recall: 0.8838383838383839
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 18 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.10718140006065369, 0.9792503118515015, 0.932584285736084, 0.8858785033226013] =====
#
# ===== Starting round 19 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.3886 - custom_accuracy: 0.9740 - val_loss: 1.4205 - val_custom_accuracy: 0.9745
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3888 - custom_accuracy: 0.9733 - val_loss: 1.4308 - val_custom_accuracy: 0.9742
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3744 - custom_accuracy: 0.9764 - val_loss: 1.4348 - val_custom_accuracy: 0.9752
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3820 - custom_accuracy: 0.9766 - val_loss: 1.4232 - val_custom_accuracy: 0.9732
# Epoch 5/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3705 - custom_accuracy: 0.9783 - val_loss: 1.4374 - val_custom_accuracy: 0.9748
# Epoch 6/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3639 - custom_accuracy: 0.9786 - val_loss: 1.4223 - val_custom_accuracy: 0.9748
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3671 - custom_accuracy: 0.9789 - val_loss: 1.4215 - val_custom_accuracy: 0.9750
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3623 - custom_accuracy: 0.9801 - val_loss: 1.4299 - val_custom_accuracy: 0.9769
# Epoch 9/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3618 - custom_accuracy: 0.9797 - val_loss: 1.4386 - val_custom_accuracy: 0.9779
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3583 - custom_accuracy: 0.9808 - val_loss: 1.4287 - val_custom_accuracy: 0.9758
# Client 1 - Last epoch validation: Loss: 1.4286555051803589, Accuracy: 0.9757601618766785, F1: 0.8746335522554946, Precision: 0.9247967877895872, Recall: 0.8551980198019802
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.4009 - custom_accuracy: 0.9678 - val_loss: 1.4351 - val_custom_accuracy: 0.9732
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3854 - custom_accuracy: 0.9734 - val_loss: 1.4437 - val_custom_accuracy: 0.9716
# Epoch 3/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3801 - custom_accuracy: 0.9743 - val_loss: 1.4457 - val_custom_accuracy: 0.9736
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3748 - custom_accuracy: 0.9754 - val_loss: 1.4593 - val_custom_accuracy: 0.9727
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3687 - custom_accuracy: 0.9774 - val_loss: 1.4698 - val_custom_accuracy: 0.9745
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3677 - custom_accuracy: 0.9777 - val_loss: 1.4702 - val_custom_accuracy: 0.9750
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3673 - custom_accuracy: 0.9784 - val_loss: 1.4884 - val_custom_accuracy: 0.9752
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3653 - custom_accuracy: 0.9789 - val_loss: 1.5066 - val_custom_accuracy: 0.9746
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3663 - custom_accuracy: 0.9789 - val_loss: 1.4900 - val_custom_accuracy: 0.9760
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3695 - custom_accuracy: 0.9784 - val_loss: 1.4637 - val_custom_accuracy: 0.9735
# Client 2 - Last epoch validation: Loss: 1.4637237787246704, Accuracy: 0.9734652638435364, F1: 0.87612417390333, Precision: 0.9105045410535083, Recall: 0.8576555023923444
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 7s 23ms/step - loss: 1.3999 - custom_accuracy: 0.9691 - val_loss: 1.3959 - val_custom_accuracy: 0.9749
# Epoch 2/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3814 - custom_accuracy: 0.9738 - val_loss: 1.4025 - val_custom_accuracy: 0.9781
# Epoch 3/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3748 - custom_accuracy: 0.9756 - val_loss: 1.4087 - val_custom_accuracy: 0.9791
# Epoch 4/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3704 - custom_accuracy: 0.9785 - val_loss: 1.4085 - val_custom_accuracy: 0.9772
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3679 - custom_accuracy: 0.9773 - val_loss: 1.4090 - val_custom_accuracy: 0.9789
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3660 - custom_accuracy: 0.9795 - val_loss: 1.4096 - val_custom_accuracy: 0.9781
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3623 - custom_accuracy: 0.9809 - val_loss: 1.4249 - val_custom_accuracy: 0.9782
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3642 - custom_accuracy: 0.9796 - val_loss: 1.4237 - val_custom_accuracy: 0.9753
# Epoch 9/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3607 - custom_accuracy: 0.9801 - val_loss: 1.4114 - val_custom_accuracy: 0.9763
# Epoch 10/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3646 - custom_accuracy: 0.9792 - val_loss: 1.4155 - val_custom_accuracy: 0.9759
# Client 3 - Last epoch validation: Loss: 1.4155291318893433, Accuracy: 0.9759036302566528, F1: 0.8847029624168489, Precision: 0.9142199011360695, Recall: 0.875
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 19 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.09936851263046265, 0.9778638482093811, 0.9224839210510254, 0.8842364549636841] =====
#
# ===== Starting round 20 of federated learning =====
#
# --- Training with FedProx aggregation ---
#
# --- Training on client 1 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 23ms/step - loss: 1.3964 - custom_accuracy: 0.9719 - val_loss: 1.4692 - val_custom_accuracy: 0.9743
# Epoch 2/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3837 - custom_accuracy: 0.9756 - val_loss: 1.4470 - val_custom_accuracy: 0.9775
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3690 - custom_accuracy: 0.9777 - val_loss: 1.4515 - val_custom_accuracy: 0.9753
# Epoch 4/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3675 - custom_accuracy: 0.9793 - val_loss: 1.4373 - val_custom_accuracy: 0.9749
# Epoch 5/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3663 - custom_accuracy: 0.9788 - val_loss: 1.4377 - val_custom_accuracy: 0.9748
# Epoch 6/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3642 - custom_accuracy: 0.9802 - val_loss: 1.4335 - val_custom_accuracy: 0.9752
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3617 - custom_accuracy: 0.9813 - val_loss: 1.4382 - val_custom_accuracy: 0.9759
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3620 - custom_accuracy: 0.9801 - val_loss: 1.4536 - val_custom_accuracy: 0.9758
# Epoch 9/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3603 - custom_accuracy: 0.9808 - val_loss: 1.4538 - val_custom_accuracy: 0.9749
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3576 - custom_accuracy: 0.9811 - val_loss: 1.4453 - val_custom_accuracy: 0.9756
# Client 1 - Last epoch validation: Loss: 1.4453073740005493, Accuracy: 0.9756167531013489, F1: 0.8749535011449998, Precision: 0.9260582773826685, Recall: 0.8576732673267327
# --- Training on client 1 completed ---
#
# --- Training on client 2 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 24ms/step - loss: 1.4013 - custom_accuracy: 0.9688 - val_loss: 1.4502 - val_custom_accuracy: 0.9738
# Epoch 2/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3848 - custom_accuracy: 0.9726 - val_loss: 1.4577 - val_custom_accuracy: 0.9756
# Epoch 3/10
# 249/249 [==============================] - 5s 22ms/step - loss: 1.3855 - custom_accuracy: 0.9747 - val_loss: 1.4416 - val_custom_accuracy: 0.9762
# Epoch 4/10
# 249/249 [==============================] - 5s 22ms/step - loss: 1.3725 - custom_accuracy: 0.9767 - val_loss: 1.4415 - val_custom_accuracy: 0.9743
# Epoch 5/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3678 - custom_accuracy: 0.9781 - val_loss: 1.4487 - val_custom_accuracy: 0.9755
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3673 - custom_accuracy: 0.9785 - val_loss: 1.4507 - val_custom_accuracy: 0.9746
# Epoch 7/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3647 - custom_accuracy: 0.9791 - val_loss: 1.4744 - val_custom_accuracy: 0.9749
# Epoch 8/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3620 - custom_accuracy: 0.9800 - val_loss: 1.4630 - val_custom_accuracy: 0.9758
# Epoch 9/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3622 - custom_accuracy: 0.9794 - val_loss: 1.4837 - val_custom_accuracy: 0.9756
# Epoch 10/10
# 249/249 [==============================] - 4s 17ms/step - loss: 1.3645 - custom_accuracy: 0.9805 - val_loss: 1.4509 - val_custom_accuracy: 0.9743
# Client 2 - Last epoch validation: Loss: 1.4508856534957886, Accuracy: 0.9743258953094482, F1: 0.8810810950008736, Precision: 0.8965897985697033, Recall: 0.8755980861244019
# --- Training on client 2 completed ---
#
# --- Training on client 3 ---
# Epoch 1/10
# 249/249 [==============================] - 8s 24ms/step - loss: 1.4016 - custom_accuracy: 0.9689 - val_loss: 1.3930 - val_custom_accuracy: 0.9742
# Epoch 2/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3823 - custom_accuracy: 0.9738 - val_loss: 1.3975 - val_custom_accuracy: 0.9753
# Epoch 3/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3754 - custom_accuracy: 0.9759 - val_loss: 1.3980 - val_custom_accuracy: 0.9762
# Epoch 4/10
# 249/249 [==============================] - 5s 21ms/step - loss: 1.3746 - custom_accuracy: 0.9767 - val_loss: 1.3927 - val_custom_accuracy: 0.9769
# Epoch 5/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3678 - custom_accuracy: 0.9779 - val_loss: 1.3977 - val_custom_accuracy: 0.9783
# Epoch 6/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3656 - custom_accuracy: 0.9786 - val_loss: 1.3980 - val_custom_accuracy: 0.9789
# Epoch 7/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3625 - custom_accuracy: 0.9800 - val_loss: 1.4104 - val_custom_accuracy: 0.9778
# Epoch 8/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3657 - custom_accuracy: 0.9792 - val_loss: 1.4048 - val_custom_accuracy: 0.9783
# Epoch 9/10
# 249/249 [==============================] - 4s 15ms/step - loss: 1.3639 - custom_accuracy: 0.9800 - val_loss: 1.4111 - val_custom_accuracy: 0.9781
# Epoch 10/10
# 249/249 [==============================] - 4s 16ms/step - loss: 1.3600 - custom_accuracy: 0.9817 - val_loss: 1.4191 - val_custom_accuracy: 0.9763
# Client 3 - Last epoch validation: Loss: 1.4191248416900635, Accuracy: 0.9763339161872864, F1: 0.8896223565634203, Precision: 0.9057126322444613, Recall: 0.8838383838383839
# --- Training on client 3 completed ---
#
# *** Aggregating client model weights (FedProx) ***
# *** Global model weights updated (FedProx) ***
#
# ===== Post-round 20 global model evaluation (FedProx): ['loss', 'custom_accuracy', 'precision', 'recall'] = [0.09938018023967743, 0.9792025089263916, 0.9266524314880371, 0.8920361399650574] =====
